# %%
import pandas as pd

# %%
#Create a variable for file directory

file_dir = 'C://Users/keemah/Class/archive/'

# %%
#Read the Kaggle data files

kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}archive/ratings.csv')

# %%
#Inspect a sample of the kaggle metadata dataframe

kaggle_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection    budget  \
# 44277  False                                                NaN         0
# 42436  False  {'id': 436483, 'name': 'Bad Kids Collection', ...   5000000
# 42167  False                                                NaN         0
# 1525   False                                                NaN  75000000
# 3628   False                                                NaN         0
#
#                                                   genres  \
# 44277  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 42436  [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 42167  [{'id': 53, 'name': 'Thriller'}, {'id': 12, 'n...
# 1525   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 3628                                                  []
#
#                                  homepage      id    imdb_id  \
# 44277                                 NaN   30885  tt0072354
# 42436  https://www.crestview-academy.com/  426580  tt3349578
# 42167                                 NaN  401222  tt2278870
# 1525                                  NaN    8834  tt0118883
# 3628                                  NaN  207731  tt0217287
#
#       original_language                 original_title  \
# 44277                en                       Vampyres
# 42436                en  Bad Kids of Crestview Academy
# 42167                en                        ISRA 88
# 1525                 en              Conspiracy Theory
# 3628                 en                 Boricua's Bond
#
#                                                 overview  ... release_date  \
# 44277  A lesbian vampire couple haunt an abandoned ca...  ...   1974-01-01
# 42436  It's four years later, and a new group of stud...  ...   2017-01-13
# 42167  When a scientist and a pilot volunteer for a h...  ...   2016-08-08
# 1525   A man obsessed with conspiracy theories become...  ...   1997-08-07
# 3628   Tommy, a talented Puerto Rican painter living ...  ...          NaN
#
#            revenue runtime                          spoken_languages  \
# 44277          0.0    87.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 42436          0.0   100.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 42167          0.0   119.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 1525   136982834.0   135.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 3628           0.0   105.0                                        []
#
#          status                                            tagline  \
# 44277  Released  They shared the pleasures of the flesh, and th...
# 42436  Released                Detention sucks but it's killer fun
# 42167  Released  Their mission was to reach the edge of the uni...
# 1525   Released  What if your most paranoid nightmares had just...
# 3628   Released                                                NaN
#
#                                title  video vote_average vote_count
# 44277                       Vampyres  False          4.6       17.0
# 42436  Bad Kids of Crestview Academy  False          4.8       13.0
# 42167                        ISRA 88  False          5.0       13.0
# 1525               Conspiracy Theory  False          6.5      440.0
# 3628                  Boricua's Bond  False          2.0        1.0
#
# [5 rows x 24 columns]

# %%
#Inspect a sample of the ratings dataframe

ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 15215292  158338       17     5.0   856213615
# 1081730    11042     1617     4.5  1065061997
# 22921955  238064    39398     4.5  1199137629
# 12378120  128401      288     3.0   829637515
# 3040548    31773     8340     4.5  1119027286
